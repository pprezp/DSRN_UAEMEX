# %% [markdown]
# # Introducción a Matplotlib

# %% [markdown]
# [Matplotlib](https://matplotlib.org) es una librería que permite la creación de figuras y gráficos de calidad mediante el uso de Python.
# * Permite la creación de gráficos de manera sencilla y eficiente
# * Permite la integración de gráficos y figuras en un Jupyter Notebook

# %% [markdown]
# ## Instalar matplotlib
# Se puede instalar usando la instrucción
#
# pip instal matplotlib
# desde la terminal del entorno en el que se esté trabajando

# %% [markdown]
# ## Import

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# Muestrar los gráficos integrados dentro de jupyter notebook
# %matplotlib inline

# %% [markdown]
# ## Representación gráfica de datos

# %% [markdown]
# Si a la función de trazado se le da una matriz de datos, la usará como coordenadas en el eje vertical, y utilizará el índice de cada punto de datos en el array como la coordenada horizontal.

# %%
lista = [ 1, 2, 5, 7, 8, 3, 1 ]

plt.plot(lista)

# %% [markdown]
# También se puede proporcionar dos matrices: una para el eje horizontal, y otra para el eje vertical.

# %%
lista2 = [ 1, 4, 6, 7, 8, 9, 10 ]
plt.plot(lista2, lista)
plt.show()

# %% [markdown]
# Pueden modificarse las logitudes de los ejes para que la figura no se vea tan ajustada

# %%
plt.plot([ -3, -1, 0, 4, 7 ], [ 1, 4, 6, 7, 8 ] )
plt.show()

# %%
plt.plot( [ -3, -1, 0, 4, 7 ], [ 1, 4, 6, 7, 8 ] )
plt.axis( [ -4, 8, 0, 10 ] )
plt.show()

# %% [markdown]
# Se sigue el mismo procedimiento para pintar una función matemática

# %%
import numpy as np

x = np.linspace( -2, 2, 500 )
x
# Out:
# array([-2.        , -1.99198397, -1.98396794, -1.9759519 , -1.96793587,
#        -1.95991984, -1.95190381, -1.94388778, -1.93587174, -1.92785571,
#        -1.91983968, -1.91182365, -1.90380762, -1.89579158, -1.88777555,
#        -1.87975952, -1.87174349, -1.86372745, -1.85571142, -1.84769539,
#        -1.83967936, -1.83166333, -1.82364729, -1.81563126, -1.80761523,
#        -1.7995992 , -1.79158317, -1.78356713, -1.7755511 , -1.76753507,
#        -1.75951904, -1.75150301, -1.74348697, -1.73547094, -1.72745491,
#        -1.71943888, -1.71142285, -1.70340681, -1.69539078, -1.68737475,
#        -1.67935872, -1.67134269, -1.66332665, -1.65531062, -1.64729459,
#        -1.63927856, -1.63126253, -1.62324649, -1.61523046, -1.60721443,
#        -1.5991984 , -1.59118236, -1.58316633, -1.5751503 , -1.56713427,
#        -1.55911824, -1.5511022 , -1.54308617, -1.53507014, -1.52705411,
#        -1.51903808, -1.51102204, -1.50300601, -1.49498998, -1.48697395,
# ...

# %%
y = x**2

plt.plot(x, y)
plt.show()

# %% [markdown]
# También pude modificarse el estilo de la gráfica para que contenga más información.

# %%
plt.plot(x, y)
plt.title("Square Function")
plt.xlabel("X")
plt.ylabel("Y = X**2")
plt.grid(True)
plt.plot()
# Out:
# []

# %% [markdown]
# Pueden superponerse gráficas y cambiar el estilo de las líneas

# %%
x = np.linspace( -2, 2, 500)
y = x**2

y2 = x + 1

plt.plot(x, y, 'b--', x, y2, 'g')
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Separando en diferentes lineas las funciones
x = np.linspace( -2, 2, 500)
y = x**2

y2 = x + 1

plt.plot(x, y, 'r--')
plt.plot(x, y2, 'o')

plt.show()

# %% [markdown]
# Para poder diferenciar entre ambas funciones siempre es recomendable añadir una leyenda

# %%
x = np.linspace( -2, 2, 500)
y = x**2

y2 = x + 1

plt.plot(x, y, 'r--', label = "x**2" )
plt.plot(x, y2, 'o', label = "x+1" )
plt.legend(loc="best")
plt.show()

# %% [markdown]
# Tambien puede crearse dos graficas que no se superpongan. Estas graficas se organizan en un grid y se denominan subplots.

# %%
x = np.linspace( -2, 2, 500)
y = x**2

y2 = x + 1

plt.subplot( 1, 2, 1 )
plt.plot(x, y, 'r--', label = "x**2" )
plt.legend(loc="best")
plt.subplot( 1, 2, 2 ) ## numfilas, numColumnas, subplot
plt.plot(x, y2, 'o', label = "x+1" )
plt.legend(loc="best")
plt.show()

# %% [markdown]
# Para que las gráficas no queden tan ajustadas, podemos hacer la figura más grande.

# %%
x = np.linspace( -2, 2, 500)
y = x**2

y2 = x + 1


plt.figure( figsize = [ 20, 6 ] )
plt.subplot( 1, 2, 1 )
plt.plot( x, y, 'r--' )
plt.xlabel( "X ** 2 ", fontsize = 14 )
plt.ylabel( "y", fontsize = 14 )
plt.subplot( 1, 2, 2 ) ## numfilas, numColumnas, subplot
plt.plot( x, y2, 'o' )
plt.ylabel( "y", fontsize = 14 )
plt.xlabel( "x + 1 ", fontsize = 14 )
plt.show()

# %% [markdown]
# ## Scatter plots

# %%
from numpy.random import rand

x, y = rand(2, 100)
# Out:
# array([0.64280392, 0.84106638, 0.60219128, 0.09828242, 0.77201174,
#        0.53696684, 0.54158803, 0.71363259, 0.11898747, 0.79303873,
#        0.43407335, 0.0443775 , 0.93730992, 0.62240148, 0.29236286,
#        0.28890574, 0.36584308, 0.61414264, 0.69571669, 0.87577835,
#        0.73803923, 0.34012025, 0.48763963, 0.99609216, 0.87201903,
#        0.00406943, 0.61012066, 0.84562414, 0.92211093, 0.42493829,
#        0.90683689, 0.67917727, 0.37074426, 0.4512084 , 0.55571268,
#        0.215841  , 0.7473334 , 0.49514088, 0.08405377, 0.10087496,
#        0.63575885, 0.05858591, 0.77271164, 0.39586041, 0.87918038,
#        0.28048342, 0.29822536, 0.09313275, 0.36883141, 0.69533837,
#        0.70702417, 0.75598893, 0.90583527, 0.59990048, 0.97671034,
#        0.46073211, 0.83664945, 0.12979368, 0.47957384, 0.02435811,
#        0.57865374, 0.01725417, 0.91984608, 0.11682637, 0.5178992 ,
#        0.7384173 , 0.57527439, 0.92296043, 0.10175179, 0.38481461,
# ...

# %%
x
# Out:
# array([0.47015455, 0.23434295, 0.14932453, 0.73442433, 0.74765913,
#        0.17981167, 0.88887113, 0.37153465, 0.62446318, 0.58960133,
#        0.92626983, 0.41127928, 0.34343347, 0.18906563, 0.57444473,
#        0.60406373, 0.33136536, 0.51283882, 0.37275366, 0.49518878,
#        0.96516181, 0.7337094 , 0.84520568, 0.79065376, 0.71299936,
#        0.91755718, 0.29316342, 0.96569811, 0.79656981, 0.89183142,
#        0.13432867, 0.91167131, 0.21177026, 0.47265801, 0.90352419,
#        0.06088624, 0.63328853, 0.60774306, 0.12360684, 0.52939444,
#        0.10957315, 0.15119547, 0.24844349, 0.17884393, 0.20583566,
#        0.95250215, 0.49201897, 0.44306439, 0.86923785, 0.55586508,
#        0.71385094, 0.82379108, 0.84430561, 0.38273132, 0.2944882 ,
#        0.19056213, 0.99524428, 0.93959999, 0.78401338, 0.40714574,
#        0.29549202, 0.21054127, 0.44952375, 0.46952405, 0.00286676,
#        0.34672044, 0.58297183, 0.30732008, 0.32799016, 0.11619261,
# ...

# %%
y
# Out:
# array([0.64280392, 0.84106638, 0.60219128, 0.09828242, 0.77201174,
#        0.53696684, 0.54158803, 0.71363259, 0.11898747, 0.79303873,
#        0.43407335, 0.0443775 , 0.93730992, 0.62240148, 0.29236286,
#        0.28890574, 0.36584308, 0.61414264, 0.69571669, 0.87577835,
#        0.73803923, 0.34012025, 0.48763963, 0.99609216, 0.87201903,
#        0.00406943, 0.61012066, 0.84562414, 0.92211093, 0.42493829,
#        0.90683689, 0.67917727, 0.37074426, 0.4512084 , 0.55571268,
#        0.215841  , 0.7473334 , 0.49514088, 0.08405377, 0.10087496,
#        0.63575885, 0.05858591, 0.77271164, 0.39586041, 0.87918038,
#        0.28048342, 0.29822536, 0.09313275, 0.36883141, 0.69533837,
#        0.70702417, 0.75598893, 0.90583527, 0.59990048, 0.97671034,
#        0.46073211, 0.83664945, 0.12979368, 0.47957384, 0.02435811,
#        0.57865374, 0.01725417, 0.91984608, 0.11682637, 0.5178992 ,
#        0.7384173 , 0.57527439, 0.92296043, 0.10175179, 0.38481461,
# ...

# %%
plt.scatter(x, y)
plt.show()

# %%
x, y = rand(2, 100)
x2, y2 = rand(2, 100)

plt.scatter( x, y, c = 'red')
plt.scatter( x2, y2, c = 'green')
plt.show()

# %% [markdown]
# ## Histogramas

# %%
data = [1, 1.1, 1.8, 2, 2.1, 3.2, 3, 3, 3, 3]

plt.figure( figsize = [ 10, 8 ] )

plt.subplot(211)
plt.hist(data, bins= 22, rwidth= 0.8)
plt.xlabel("valor")
plt.ylabel("frecuencia")

plt.subplot(212)
plt.hist(data, bins= [ 1, 1.5, 2, 2.5, 3 ], rwidth= 0.8)
plt.xlabel("valor")
plt.ylabel("frecuencia")

plt.show()

# %% [markdown]
# ## Guardar las figuras

# %%
x = np.linspace( -2, 2, 500)
y = x**2

y2 = x + 1


plt.figure( figsize = [ 10, 6 ] )
plt.title("Function Sqare")
plt.plot( x, y, 'r--', label="x**2")
plt.plot( x, y2, 'o', label="x + 1")
plt.legend("best")

plt.savefig("grafiquita.png", transparent=True)
