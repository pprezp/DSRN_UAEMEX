# %% [markdown]
# # Actividad. Perceptrón de para obtener la relación velocidad - altura
#
# <table>
#     <head>
#         <tr>
# 			<th colspan="2">Caracteristicas</th>
# 			<th>Resultado Esperado</th>
#         </tr>
#         <tr>
# 			<th>Altura</th>
# 			<th>velocidad</th>
# 			<th>Aceleración</th>
#         </tr>
#     </head>
#     <body>
#         <tr>
# 			<td style="text-align:center">0</td>
# 			<td style="text-align:center">0</td>
# 			<td style="text-align:center">350</td>
#         </tr>
#         <tr>
# 			<td style="text-align:center">0</td>
# 			<td style="text-align:center">1</td>
# 			<td style="text-align:center">200</td>
#         </tr>
#         <tr>
# 			<td style="text-align:center">1</td>
# 			<td style="text-align:center">0</td>
# 			<td style="text-align:center">200</td>
#         </tr>
#         <tr>
# 			<td style="text-align:center">1</td>
# 			<td style="text-align:center">1</td>
# 			<td style="text-align:center">200</td>
#         </tr>
#     </body>
# </table>

# %%
# Definiendo la función a utilizar en el perceptrón

# Importando las librerías a utilizar
import numpy as np

# Definición de la función Relu
#   La salida es el máximo entre 0 y la suma ponderada
def relu( sumaPonderada ):
    return max( 0, sumaPonderada )

# %%
# Realizando código del cuerpo del perceptrón

# Definición de las entradas de la tabla de verdad
entradas = np.array( [ [ 0, 0 ], [ 0, 1 ],[ 1, 0 ],  [ 1, 1 ] ] )

# Definión de los resultados esperados del procesamiento de la información por el perceptrón
resultadoEsperado = np.array( [ 350, 200, 200, 50 ] )

# Variable donde se almacenaran los resultados obtenidos
salidas = []

#
pesos = np.array( [ -150, -150 ])
bias = 350

# Para cada entrada ejecuta el procedimiento del perceptrón almacena el resultado en el arreglo de las salidas
for i in range( resultadoEsperado.shape[0] ):
    h = np.dot( entradas[i], pesos ) + bias
    y = relu( h )
    salidas.append( [ h, y ] )


#Imprimiendo los valores despues de la ejecución del perceptrón

# Para cada entrada ejecuta el procedimiento del perceptrón almacena el resultado en el arreglo de las salidas
for i in range( resultadoEsperado.shape[0] ):
    h = np.dot( entradas[i], pesos ) + bias
    y = relu( h )
    salidas.append( [ h, y ] )

# Imprimiendo la salida
print( 'Input1', 'Input2', 'Combinación Lineal', 'Target', 'Salida' )

for i in range( 4 ):
    print( entradas[i][0], entradas[i][1], salidas[i][0],  resultadoEsperado[i], str( salidas[i][1] ), sep='        '  )
# Out:
# Input1 Input2 Combinación Lineal Target Salida
# 0        0        350        350        350
# 0        1        200        200        200
# 1        0        200        200        200
# 1        1        50        50        50
