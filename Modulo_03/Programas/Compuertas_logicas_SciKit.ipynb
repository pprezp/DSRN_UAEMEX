# %% [markdown]
# # Actividad de tarea: Compuertas lógicas con aprendizaje autom&aacute;tico con SciKit Learn

# %% [markdown]
# ## Cálculo de la compuerta AND

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
# %matplotlib inline

# Definición de las entradas de la tabla de verdad
entradas = np.array( [ [ 0, 0 ], [ 0, 1 ], [ 1, 0 ], [ 1, 1 ] ] )

# Definión de los resultados esperados del procesamiento de la información por el perceptrón
resultadoEsperado = np.array( [ 0, 0, 0, 1 ] )

# Definiendo el perceptron que realizará los cálculos de la compuerta
modelo = Perceptron(eta0=0.1, max_iter=1, warm_start=True)

# Definición de las epocas
epocas = 10

# Inicializando los arreglos donde se almacenaran los valores y las epocas correspondientes
errores_x_epoca = []
epocas_tiempo = []

#Entrenando la 1er vez el perceptrón, para obtener los valores iniciales
modelo.partial_fit(entradas, resultadoEsperado, classes=np.array([0,1]))

#Imprimiendo los valores iniciales
print("\nPesos Iniciales")
print("Weights:", modelo.coef_)
print("Bias:", modelo.intercept_)

# Iterando sobre x número de épocas
for epoca in range(epocas):

    # Entrenando el modelo por época
    modelo.partial_fit(entradas, resultadoEsperado)

    # Obteniendo las predicciones
    predicciones = modelo.predict(entradas)

    # Obteniendo los errores
    error = np.sum(predicciones != resultadoEsperado)
    errores_x_epoca.append(error)

    # Añadiendo la época correspondiente
    epocas_tiempo.append( epoca + 1)

    # Imprimiendo los valores obtenidos por cada época
    print(f"\nÉpoca {epoca+1}")
    print("Predicciones:", predicciones)
    print("Error:", error)
    print("Weights:", modelo.coef_)
    print("Bias:", modelo.intercept_)

    # Agregando paro condicionado
    if error == 0:
        break

# Imprimiendo los valores finales obtenidos
print("\nPesos Finales")
print("Weights:", modelo.coef_)
print("Bias:", modelo.intercept_)

# Procediendo a a graficar los valores de errores totales por épocas
plt.plot( epocas_tiempo, errores_x_epoca )
plt.title('Errores a través de las epocas para la compuerta AND')
plt.ylabel('No. de Errores')
plt.xlabel('Epocas')
plt.xticks( range(1, np.max( epocas_tiempo ) + 1 ) )
plt.yticks(range(0, np.max( errores_x_epoca ) + 1 ) )
plt.autoscale(True)
plt.show()
# Out:
# Pesos Iniciales
# Weights: [[0. 0.]]
# Bias: [-0.1]
#
# Época 1
# Predicciones: [0 0 0 0]
# Error: 1
# Weights: [[0. 0.]]
# Bias: [-0.2]
#
# Época 2
# Predicciones: [0 0 0 0]
# Error: 1
# Weights: [[0.1 0. ]]
# Bias: [-0.2]
#
# Época 3
# Predicciones: [0 0 0 0]
# Error: 1
# Weights: [[0.1 0. ]]
# Bias: [-0.3]
#
# Época 4
# Predicciones: [0 0 0 1]
# Error: 0
# Weights: [[0.2 0.1]]
# Bias: [-0.2]
#
# Pesos Finales
# Weights: [[0.2 0.1]]
# Bias: [-0.2]

# %% [markdown]
# ## Cálculo de la compuerta NOT

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
# %matplotlib inline

# Definición de las entradas de la tabla de verdad
entradas = np.array( [ [ 0, 0 ], [ 0, 1 ], [ 1, 0 ], [ 1, 1 ] ] )

# Definión de los resultados esperados del procesamiento de la información por el perceptrón
resultadoEsperado = np.array( [ 1, 1, 0, 0 ] )

# Definiendo el perceptron que realizará los cálculos de la compuerta
modelo = Perceptron(eta0=0.1, max_iter=1, warm_start=True)

# Definición de las epocas
epocas = 10

# Inicializando los arreglos donde se almacenaran los valores y las epocas correspondientes
errores_x_epoca = []
epocas_tiempo = []

#Entrenando la 1er vez el perceptrón, para obtener los valores iniciales
modelo.partial_fit(entradas, resultadoEsperado, classes=np.array([0,1]))

#Imprimiendo los valores iniciales
print("\nPesos Iniciales")
print("Weights:", modelo.coef_)
print("Bias:", modelo.intercept_)

# Iterando sobre x número de épocas
for epoca in range(epocas):

    # Entrenando el modelo por época
    modelo.partial_fit(entradas, resultadoEsperado)

    # Obteniendo las predicciones
    predicciones = modelo.predict(entradas)

    # Obteniendo los errores
    error = np.sum(predicciones != resultadoEsperado)
    errores_x_epoca.append(error)

    # Añadiendo la época correspondiente
    epocas_tiempo.append( epoca + 1)

    # Imprimiendo los valores obtenidos por cada época
    print(f"\nÉpoca {epoca+1}")
    print("Predicciones:", predicciones)
    print("Error:", error)
    print("Weights:", modelo.coef_)
    print("Bias:", modelo.intercept_)

# Imprimiendo los valores finales obtenidos
print("\nPesos Finales")
print("Weights:", modelo.coef_)
print("Bias:", modelo.intercept_)

# Procediendo a a graficar los valores de errores totales por épocas
plt.plot( epocas_tiempo, errores_x_epoca )
plt.title('Errores a través de las epocas para la compuerta NOT')
plt.ylabel('No. de Errores')
plt.xlabel('Epocas')
plt.xticks( range(1, np.max( epocas_tiempo ) + 1 ) )
plt.yticks(range(0, np.max( errores_x_epoca ) + 1 ) )
plt.autoscale(True)
plt.show()
# Out:
# Pesos Iniciales
# Weights: [[-0.1  0. ]]
# Bias: [0.1]
#
# Época 1
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 2
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 3
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 4
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 5
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 6
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 7
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 8
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 9
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Época 10
# Predicciones: [1 1 0 0]
# Error: 0
# Weights: [[-0.2  0. ]]
# Bias: [0.1]
#
# Pesos Finales
# Weights: [[-0.2  0. ]]
# Bias: [0.1]

# %% [markdown]
# ## Cálculo de la compuerta NOR

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
# %matplotlib inline

# Definición de las entradas de la tabla de verdad
entradas = np.array( [ [ 0, 0 ], [ 0, 1 ], [ 1, 0 ], [ 1, 1 ] ] )

# Definión de los resultados esperados del procesamiento de la información por el perceptrón
resultadoEsperado = np.array( [ 1, 0, 0, 0 ] )

# Definiendo el perceptron que realizará los cálculos de la compuerta
modelo = Perceptron(eta0=0.1, max_iter=1, warm_start=True)

# Definición de las epocas
epocas = 10

# Inicializando los arreglos donde se almacenaran los valores y las epocas correspondientes
errores_x_epoca = []
epocas_tiempo = []

#Entrenando la 1er vez el perceptrón, para obtener los valores iniciales
modelo.partial_fit(entradas, resultadoEsperado, classes=np.array([0,1]))

#Imprimiendo los valores iniciales
print("\nPesos Iniciales")
print("Weights:", modelo.coef_)
print("Bias:", modelo.intercept_)

# Iterando sobre x número de épocas
for epoca in range(epocas):

    # Entrenando el modelo por época
    modelo.partial_fit(entradas, resultadoEsperado)

    # Obteniendo las predicciones
    predicciones = modelo.predict(entradas)

    # Obteniendo los errores
    error = np.sum(predicciones != resultadoEsperado)
    errores_x_epoca.append(error)

    # Añadiendo la época correspondiente
    epocas_tiempo.append( epoca + 1)

    # Imprimiendo los valores obtenidos por cada época
    print(f"\nÉpoca {epoca+1}")
    print("Predicciones:", predicciones)
    print("Error:", error)
    print("Weights:", modelo.coef_)
    print("Bias:", modelo.intercept_)

# Imprimiendo los valores finales obtenidos
print("\nPesos Finales")
print("Weights:", modelo.coef_)
print("Bias:", modelo.intercept_)

# Procediendo a a graficar los valores de errores totales por épocas
plt.plot( epocas_tiempo, errores_x_epoca )
plt.title('Errores a través de las epocas para la compuerta NOR')
plt.ylabel('No. de Errores')
plt.xlabel('Epocas')
plt.xticks( range(1, np.max( epocas_tiempo ) + 1 ) )
plt.yticks(range(0, np.max( errores_x_epoca ) + 1 ) )
plt.autoscale(True)
plt.show()
# Out:
# Pesos Iniciales
# Weights: [[-0.1 -0.1]]
# Bias: [0.]
#
# Época 1
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.1 -0.1]]
# Bias: [0.1]
#
# Época 2
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.1 -0.2]]
# Bias: [0.1]
#
# Época 3
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]
#
# Época 4
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]
#
# Época 5
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]
#
# Época 6
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]
#
# Época 7
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]
#
# Época 8
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]
#
# Época 9
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]
#
# Época 10
# Predicciones: [1 0 0 0]
# Error: 0
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]
#
# Pesos Finales
# Weights: [[-0.2 -0.2]]
# Bias: [0.1]

# %% [markdown]
# ## Cálculo de la compuerta OR

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
# %matplotlib inline

# Definición de las entradas de la tabla de verdad
entradas = np.array( [ [ 0, 0 ], [ 0, 1 ], [ 1, 0 ], [ 1, 1 ] ] )

# Definión de los resultados esperados del procesamiento de la información por el perceptrón
resultadoEsperado = np.array( [ 0, 1, 1, 1 ] )

# Definiendo el perceptron que realizará los cálculos de la compuerta
modelo = Perceptron(eta0=0.1, max_iter=1, warm_start=True)

# Definición de las epocas
epocas = 10

# Inicializando los arreglos donde se almacenaran los valores y las epocas correspondientes
errores_x_epoca = []
epocas_tiempo = []

#Entrenando la 1er vez el perceptrón, para obtener los valores iniciales
modelo.partial_fit(entradas, resultadoEsperado, classes=np.array([0,1]))

#Imprimiendo los valores iniciales
print("\nPesos Iniciales")
print("Weights:", modelo.coef_)
print("Bias:", modelo.intercept_)

# Iterando sobre x número de épocas
for epoca in range(epocas):

    # Entrenando el modelo por época
    modelo.partial_fit(entradas, resultadoEsperado)

    # Obteniendo las predicciones
    predicciones = modelo.predict(entradas)

    # Obteniendo los errores
    error = np.sum(predicciones != resultadoEsperado)
    errores_x_epoca.append(error)

    # Añadiendo la época correspondiente
    epocas_tiempo.append( epoca + 1)

    # Imprimiendo los valores obtenidos por cada época
    print(f"\nÉpoca {epoca+1}")
    print("Predicciones:", predicciones)
    print("Error:", error)
    print("Weights:", modelo.coef_)
    print("Bias:", modelo.intercept_)

# Imprimiendo los valores finales obtenidos
print("\nPesos Finales")
print("Weights:", modelo.coef_)
print("Bias:", modelo.intercept_)

# Procediendo a a graficar los valores de errores totales por épocas
plt.plot( epocas_tiempo, errores_x_epoca )
plt.title('Errores a través de las epocas para la compuerta NOR')
plt.ylabel('No. de Errores')
plt.xlabel('Epocas')
plt.xticks( range(1, np.max( epocas_tiempo ) + 1 ) )
plt.yticks(range(0, np.max( errores_x_epoca ) + 1 ) )
plt.autoscale(True)
plt.show()
# Out:
# Pesos Iniciales
# Weights: [[0.1 0.1]]
# Bias: [0.]
#
# Época 1
# Predicciones: [0 0 0 1]
# Error: 2
# Weights: [[0.1 0.1]]
# Bias: [-0.1]
#
# Época 2
# Predicciones: [0 1 0 1]
# Error: 1
# Weights: [[0.1 0.2]]
# Bias: [-0.1]
#
# Época 3
# Predicciones: [0 1 1 1]
# Error: 0
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
#
# Época 4
# Predicciones: [0 1 1 1]
# Error: 0
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
#
# Época 5
# Predicciones: [0 1 1 1]
# Error: 0
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
#
# Época 6
# Predicciones: [0 1 1 1]
# Error: 0
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
#
# Época 7
# Predicciones: [0 1 1 1]
# Error: 0
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
#
# Época 8
# Predicciones: [0 1 1 1]
# Error: 0
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
#
# Época 9
# Predicciones: [0 1 1 1]
# Error: 0
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
#
# Época 10
# Predicciones: [0 1 1 1]
# Error: 0
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
#
# Pesos Finales
# Weights: [[0.2 0.2]]
# Bias: [-0.1]
