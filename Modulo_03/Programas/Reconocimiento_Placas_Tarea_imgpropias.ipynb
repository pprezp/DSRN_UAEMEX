# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pytesseract

from pathlib import Path

print(cv2.data.haarcascades)
# Out:
# c:\Users\Pablo Perez\anaconda3\envs\DSRNArtificiales\Lib\site-packages\cv2\data\

# %% [markdown]
# ## Detección de Placa Mexicana para propias
#
#
# Solo pude hacer la deteccion de esta placa, ya que las demas placas al ser mas pequeñas o mas grandes, se debería hacer otro tipo de procesamiento mas a fondo.
#
# ## Nota:
# Detecto las placas, tuve que actualizar la escala y los vecinos dependiendo que tantos elementos tiene la imagen, obtener el area mas grande no es lo mas factible debido a que podemos tener varias coincidencias por el ruido de las imagenes, en este caso las sombras y desperfectos de los autos

# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract

img = cv2.imread('propias/placa2.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.equalizeHist(gray)

cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_russian_plate_number.xml')
plates = cascade.detectMultiScale(gray, scaleFactor=1.023, minNeighbors=3, minSize=(50,50) )

if plates.size >= 1:

    idx_mayor = np.argmax(plates[:, 2] * plates[:, 3])

    ( x, y, w, h ) = plates[idx_mayor]
    cv2.rectangle( gray, ( x, y ), ( x + w, y + h), ( 0, 255, 0 ), 3 )
    plt.imshow( gray, cmap='gray' )
    plt.show()

    resizedImg = img[ y : y + h, x : x + w, : ]
    resizedImg = cv2.cvtColor(resizedImg, cv2.COLOR_BGR2GRAY)
    resizedImg = cv2.equalizeHist(resizedImg)
    plt.imshow( resizedImg, cmap='gray' )
    plt.show()

    ret, placaBin2 = cv2.threshold( resizedImg, 180, 14, cv2.THRESH_BINARY  )
    placaBin2 = cv2.medianBlur( placaBin2, 1)

    plt.imshow( placaBin2, cmap='gray' )
    plt.show()

    textoBin2 = pytesseract.image_to_string( placaBin2 )
    print( textoBin2 )

# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract

img = cv2.imread('propias/placa1.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.equalizeHist(gray)

cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_russian_plate_number.xml')
plates = cascade.detectMultiScale(gray, scaleFactor=1.002, minNeighbors=3 )


if plates.size >= 1:

    idx_mayor = np.argmax(plates[:, 2] * plates[:, 3])

    ( x, y, w, h ) = plates[idx_mayor]
    cv2.rectangle( gray, ( x, y ), ( x + w, y + h), ( 0, 255, 0 ), 3 )
    plt.imshow( gray, cmap='gray' )
    plt.show()

    resizedImg = img[ y : y + h, x : x + w, : ]
    resizedImg = cv2.cvtColor(resizedImg, cv2.COLOR_BGR2GRAY)
    resizedImg = cv2.equalizeHist(resizedImg)
    plt.imshow( resizedImg, cmap='gray' )
    plt.show()

    ret, placaBin2 = cv2.threshold( resizedImg, 180, 1, cv2.THRESH_BINARY  )
    placaBin2 = cv2.medianBlur( placaBin2, 1)

    plt.imshow( placaBin2, cmap='gray' )
    plt.show()

    textoBin2 = pytesseract.image_to_string( placaBin2 )
    print( textoBin2 )

# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract

img = cv2.imread('propias/placa3.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.equalizeHist(gray)

cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_russian_plate_number.xml')
plates = cascade.detectMultiScale(gray, scaleFactor=1.0018, minNeighbors=8 )


if plates.size >= 1:

    idx_mayor = np.argmax(plates[:, 2] * plates[:, 3])

    ( x, y, w, h ) = plates[idx_mayor]
    cv2.rectangle( gray, ( x, y ), ( x + w, y + h), ( 0, 255, 0 ), 3 )
    plt.imshow( gray, cmap='gray' )
    plt.show()

    resizedImg = img[ y : y + h, x : x + w, : ]
    resizedImg = cv2.cvtColor(resizedImg, cv2.COLOR_BGR2GRAY)
    resizedImg = cv2.equalizeHist(resizedImg)
    plt.imshow( resizedImg, cmap='gray' )
    plt.show()

    ret, placaBin2 = cv2.threshold( resizedImg, 85, 5, cv2.THRESH_BINARY )
    placaBin2 = cv2.medianBlur( placaBin2, 1)

    plt.imshow( placaBin2, cmap='gray' )
    plt.show()

    custom_config = r'--psm 1'
    textoBin2 = pytesseract.image_to_string(placaBin2, config=custom_config)
    
    #extoBin2 = pytesseract.image_to_string( placaBin2 )
    print( textoBin2 )
